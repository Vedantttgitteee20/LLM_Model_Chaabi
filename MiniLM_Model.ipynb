# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10500\400185349.py in <module>
#       1 import pandas as pd
# ----> 2 from sentence_transformers import SentenceTransformer
#       3 model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
#
# ~\AppData\Roaming\Python\Python39\site-packages\sentence_transformers\__init__.py in <module>
#       1 __version__ = "2.2.2"
#       2 __MODEL_HUB_ORGANIZATION__ = 'sentence-transformers'
# ----> 3 from .datasets import SentencesDataset, ParallelSentencesDataset
#       4 from .LoggingHandler import LoggingHandler
#       5 from .SentenceTransformer import SentenceTransformer
#
# ~\AppData\Roaming\Python\Python39\site-packages\sentence_transformers\datasets\__init__.py in <module>
# ----> 1 from .DenoisingAutoEncoderDataset import DenoisingAutoEncoderDataset
# ...

# %%
df = pd.read_csv('bigBasketProducts.csv')
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %% [markdown]
# #### Uncomment this code when using the whole dataset

# %%
# df_small = df[:100]
# df_small

# %%
df['Concatenated'] = df.apply(lambda row: '|'.join([f'{col}:{val}' for col, val in row.items() if col != 'index']), axis=1)
df['Concatenated'][0]
# Out:
# 'product:Garlic Oil - Vegetarian Capsule 500 mg|category:Beauty & Hygiene|sub_category:Hair Care|brand:Sri Sri Ayurveda |sale_price:220.0|market_price:220.0|type:Hair Oil & Serum|rating:4.1|description:This Product contains Garlic Oil that is known to help proper digestion, maintain proper cholesterol levels, support cardiovascular and also build immunity.  For Beauty tips, tricks & more visit https://bigbasket.blog/'

# %%
sentences = df['Concatenated'].tolist()
sentences
sentence_embeddings = model.encode(sentences)
sentence_embeddings
# Out:
# array([[-0.08059409, -0.00709657, -0.03106969, ..., -0.05200696,
#          0.03726187, -0.00414216],
#        [-0.06230855,  0.035343  , -0.05885223, ..., -0.03963108,
#          0.0368353 ,  0.05928736],
#        [-0.16509321,  0.04224408,  0.03391276, ...,  0.01897744,
#          0.00123721,  0.03750814],
#        ...,
#        [-0.00908238, -0.0586436 , -0.05209364, ..., -0.02295973,
#         -0.06091567, -0.01933868],
#        [-0.00201481, -0.04641549,  0.0661734 , ..., -0.00782697,
#          0.13528955, -0.05902224],
#        [-0.01592331, -0.01955152,  0.02921385, ..., -0.10892079,
#         -0.00156971,  0.05665446]], dtype=float32)

# %%
len(sentence_embeddings[1200])
# max_dimension = np.max(sentence_embeddings)
# max_dimension
# Out:
# 384

# %%
import pinecone      

pinecone.init(      
	api_key='ec5d5e0d-f392-4654-ad4c-d030f2f8adc7',      
	environment='gcp-starter'      
)      
index = pinecone.Index('bigbasket')

# %%
index = pinecone.Index("bigbasket")

# %%
sentence_embeddings.shape
# Out:
# (27555, 384)

# %%
sentence_embeddings.shape
# Out:
# (27555, 384)

# %%
sentence_embeddings = sentence_embeddings.astype(np.float32)

# %%
index.upsert(
    vectors = vectors
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2712\2467332703.py in <module>
#       8     try:
#       9         # Upsert the vector into Pinecone
# ---> 10         index.upsert(ids=[vector['id']], vectors=[vector['values']])
#      11         print(f"Upserted vector with id {vector['id']}")
#      12     except PineconeException as e:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pinecone\core\utils\error_handling.py in inner_func(*args, **kwargs)
#      15         Config.validate()  # raises exceptions in case of invalid config
#      16         try:
# ---> 17             return func(*args, **kwargs)
#      18         except MaxRetryError as e:
#      19             if isinstance(e.reason, ProtocolError):
#
# ...

# %%
query = "Puramate"
query_embedding = model.encode([query])

# %%
res = index.query(
  vector=query_embedding[0].tolist(),
  top_k=1,
  include_values=True
)
matches = res['matches']
print("These are the top recommended products:")
for match in matches:
    id = match['id']
    product = df_small.iloc[int(id)]
    print(product)
# Out:
# These are the top recommended products:
# index                                                          37
# product                                     Pudina Chutney Masala
# category                                 Foodgrains, Oil & Masala
# sub_category                                     Masalas & Spices
# brand                                                       Catch
# sale_price                                                  46.75
# market_price                                                 55.0
# type                                              Blended Masalas
# rating                                                        3.9
# description     Catch Pudina Chutney is a spicy dip made from ...
# Concatenated    product:Pudina Chutney Masala|category:Foodgra...
# Name: 36, dtype: object

# %%
def vedant(te):
    query = "Puramate"
    query_embedding = model.encode([query])
    res = index.query(
      vector=query_embedding[0].tolist(),
      top_k=1,
      include_values=True
    )
    matches = res['matches']
    print("These are the top recommended products:")
    for match in matches:
        id = match['id']
        product = df.iloc[int(id)]
        print(product)
    return product

# %%
df_small[0:1]
# Out:
#    index                                 product          category  \
# 0      1  Garlic Oil - Vegetarian Capsule 500 mg  Beauty & Hygiene
#
#   sub_category              brand  sale_price  market_price              type  \
# 0    Hair Care  Sri Sri Ayurveda        220.0         220.0  Hair Oil & Serum
#
#    rating                                        description  \
# 0     4.1  This Product contains Garlic Oil that is known...
#
#                                         Concatenated
# 0  product:Garlic Oil - Vegetarian Capsule 500 mg...

# %%
import gradio as gr

def vedant(query):
    query = "Puramate"
    query_embedding = model.encode([query])
    res = index.query(
      vector=query_embedding[0].tolist(),
      top_k=1,
      include_values=True
    )
    matches = res['matches']
    print("These are the top recommended products:")
    for match in matches:
        id = match['id']
        product = df.iloc[int(id)]
        print(product)
    return product
    

iface = gr.Interface(fn=vedant, inputs="text", outputs="text")
iface.launch()
